# %% [markdown]
# ## **Capítulos 2 - Python Essencial: Curso Rápido para Iniciantes e Profissionais**
#
# ---

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Dilermando Piva Jr.")
# Out:
# Dilermando Piva Jr.

# %% [markdown]
# **FIM**
